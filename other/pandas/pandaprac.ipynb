# %%
import os
os.listdir()
# Out:
# ['supermarkets-commas.txt',
#  '.ipynb_checkpoints',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.xlsx',
#  'supermarkets.json',
#  'supermarkets.csv',
#  'learn_pan.py',
#  'pandaprac.ipynb']

# %%
import pandas as pd

# %%
df1 = pd.read_csv("../../data/supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pd.read_json("../../data/supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3 = pd.read_excel("../../data/supermarkets.xlsx", sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pd.read_csv("../../data/supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pd.read_csv("../../data/supermarkets-semi-colons.txt", sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6 = pd.read_csv("../../data/supermarkets.csv")
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6.columns = ["ID", "Address", "City", "ZIP", "Country", "Name", "That guy"]

# %%
df6
# Out:
#    ID          Address           City               ZIP Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    That guy
# 0         8
# 1        15
# 2        25
# 3        10
# 4        12
# 5        20

# %%
a = df6.columns[2]
a
# Out:
# 'City'

# %%
df6 = df6.set_index("ID")

# %%
df6
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     That guy
# ID
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
df6.loc["1":"4"]
# Out:
#            Address           City               ZIP Country         Name  \
# ID
# 1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3      332 Hill St  San Francisco  California 94114     USA  Super River
# 4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
#
#     That guy
# ID
# 1          8
# 2         15
# 3         25
# 4         10

# %%
df6
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     That guy
# ID
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
df6.set_index("Address", inplace=True)

# %%
df6.loc["332 Hill St", "Country"]
# Out:
# 'USA'

# %%
list(df6.loc[:,"Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df6.iloc[3,1:4]
# Out:
# ZIP          CA 94114
# Country           USA
# Name       Ben's Shop
# Name: 3995 23rd St, dtype: object

# %%
df6.drop("City", 1)
# Out:
#                               ZIP Country         Name  That guy
# Address
# 3666 21st St             CA 94114     USA      Madeira         8
# 735 Dolores St           CA 94119     USA  Bready Shop        15
# 332 Hill St      California 94114     USA  Super River        25
# 3995 23rd St             CA 94114     USA   Ben's Shop        10
# 1056 Sanchez St        California     USA      Sanchez        12
# 551 Alvarado St          CA 94114     USA   Richvalley        20

# %%
df6["Continenet"] = df6.shape[0] * ["North America"]

# %%
df6
# Out:
#                           City               ZIP Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  That guy     Continenet
# Address
# 3666 21st St            8  North America
# 735 Dolores St         15  North America
# 332 Hill St            25  North America
# 3995 23rd St           10  North America
# 1056 Sanchez St        12  North America
# 551 Alvarado St        20  North America

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-54-2f845e67b58f> in <module>
# ----> 1 from geopy.geocoders import ArcGIS
#       2 nom = ArcGIS()
#
# ModuleNotFoundError: No module named 'geopy'

# %%
# !pip3 install geopy
# Out:
# ...
#     100% |████████████████████████████████| 102kB 5.8MB/s a 0:00:01
# ...

# %%
import geopy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-55-99b9d2081153> in <module>
# ----> 1 import geopy
#
# ModuleNotFoundError: No module named 'geopy'

# %%
# !pip install geopy
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/80/93/d384479da0ead712bdaf697a8399c13a9a89bd856ada5a27d462fb45e47b/geopy-1.20.0-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/8b/62/26ec95a98ba64299163199e95ad1b0e34ad3f4e176e221c40245f211e425/geographiclib-1.50-py3-none-any.whl
# ...

# %%
import geopy

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()

# %%
nom.geocode("3995 23rd St, San Francisco, CA 94114")
# Out:
# Location(3995 23rd St, San Francisco, California, 94114, (37.752990821253434, -122.43170235858965, 0.0))
